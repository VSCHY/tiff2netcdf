# %%
# !ls
# Out:
# FLOPROS_GDPgrid.nc  Untitled.ipynb

# %%
from netCDF4 import Dataset
import numpy as np
nc = Dataset("FLOPROS_GDPgrid.nc", "r")

# %%
lon = nc.variables["longitude"][:]
lat = nc.variables["latitude"][:]

# %%
data = nc.variables["ModL_Riv"][:]

# %%
data_nan = np.where(data == -99)

# %%
data_nan[0]
# Out:
# array([  82,   82,   82, ..., 1740, 1740, 1742])

# %%
print(lon.shape, lat.shape)
# Out:
# (4320,) (2160,)

# %%
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize= (10,10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.BORDERS)


for i in range(data_nan[0].shape[0]):
    lon0 = lon[data_nan[1][i]]
    lat0 = lat[data_nan[0][i]]
    plt.plot(lon0,lat0, "ro")

plt.show()
